# %%
import pandas as pd

# %%
df = pd.read_csv('INT-Export-03-06-2023_12-08-31.csv', skiprows = [0])

# %%
df.head()
# Out:
#                      API                                     Unnamed: 1  \
# 0                    NaN  petroleum and other liquids production (Mb/d)
# 1  INTL.53-1-WORL-TBPD.A                                          World
# 2   INTL.53-1-AFG-TBPD.A                                    Afghanistan
# 3   INTL.53-1-ALB-TBPD.A                                        Albania
# 4   INTL.53-1-DZA-TBPD.A                                        Algeria
#
#                  1973                1974               1975  \
# 0                 NaN                 NaN                NaN
# 1                 NaN                 NaN                NaN
# 2                 NaN                 NaN                NaN
# 3                 NaN                 NaN                NaN
# 4  1096.9013698630138  1008.8602739726027  982.9972602739726
#
#                1976               1977                1978  \
# 0               NaN                NaN                 NaN
# ...

# %%
df.tail()
# Out:
#                       API              Unnamed: 1 1973 1974 1975 1976 1977  \
# 224  INTL.53-1-WAK-TBPD.A             Wake Island  NaN  NaN  NaN  NaN  NaN
# 225  INTL.53-1-ESH-TBPD.A          Western Sahara  NaN  NaN  NaN  NaN  NaN
# 226  INTL.53-1-YEM-TBPD.A                   Yemen  NaN  NaN  NaN  NaN  NaN
# 227  INTL.53-1-ZMB-TBPD.A                  Zambia  NaN  NaN  NaN  NaN  NaN
# 228  INTL.53-1-ZWE-TBPD.A                Zimbabwe  NaN  NaN  NaN  NaN  NaN
#
#     1978 1979 1980  ...                2012               2013  \
# 224  NaN  NaN    0  ...                   0                  0
# 225  NaN  NaN    0  ...                   0                  0
# 226  NaN  NaN    0  ...  168.94857595628415  130.7800301369863
# 227  NaN  NaN    0  ...              0.1611             0.1271
# 228  NaN  NaN    0  ...                0.12              0.039
#
#                    2014     2015               2016     2017     2018  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 51 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   API         228 non-null    object
#  1   Unnamed: 1  229 non-null    object
#  2   1973        25 non-null     object
#  3   1974        25 non-null     object
#  4   1975        25 non-null     object
#  5   1976        25 non-null     object
#  6   1977        25 non-null     object
#  7   1978        25 non-null     object
#  8   1979        25 non-null     object
#  9   1980        226 non-null    object
#  10  1981        226 non-null    object
#  11  1982        226 non-null    object
#  12  1983        226 non-null    object
#  13  1984        226 non-null    object
#  14  1985        226 non-null    object
#  15  1986        226 non-null    object
#  16  1987        226 non-null    object
#  17  1988        226 non-null    object
#  18  1989        226 non-null    object
# ...

# %%
df.shape
# Out:
# (229, 51)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df2 = df.iloc[2:228,1:51].copy().reset_index(drop=True)

# %%
df2.head(15)
# Out:
#                      Unnamed: 1                1973                1974  \
# 0                   Afghanistan                 NaN                 NaN
# 1                       Albania                 NaN                 NaN
# 2                       Algeria  1096.9013698630138  1008.8602739726027
# 3                American Samoa                 NaN                 NaN
# 4                        Angola                 162                 169
# 5                    Antarctica                 NaN                 NaN
# 6           Antigua and Barbuda                 NaN                 NaN
# 7                     Argentina                 NaN                 NaN
# 8                       Armenia                 NaN                 NaN
# 9                         Aruba                 NaN                 NaN
# 10                    Australia                 NaN                 NaN
# 11                      Austria                 NaN                 NaN
# ...

# %%
df2.rename(columns={'Unnamed: 1':'Country'}, inplace=True)

# %%
df2.head()
# Out:
#                   Country                1973                1974  \
# 0             Afghanistan                 NaN                 NaN
# 1                 Albania                 NaN                 NaN
# 2                 Algeria  1096.9013698630138  1008.8602739726027
# 3          American Samoa                 NaN                 NaN
# 4                  Angola                 162                 169
#
#                 1975              1976               1977                1978  \
# 0                NaN               NaN                NaN                 NaN
# 1                NaN               NaN                NaN                 NaN
# 2  982.9972602739726  1075.25956284153  1151.849315068493  1231.0520547945205
# 3                NaN               NaN                NaN                 NaN
# 4                165               108                194                 131
#
#                  1979                1980                1981  ...  \
# ...

# %%
df3 = df2[["Country","2021"]].copy()

# %%
df3.head(15)
# Out:
#                         Country                2021
# 0                   Afghanistan                   0
# 1                       Albania  16.150553172151987
# 2                       Algeria   1415.129339462147
# 3                American Samoa                   0
# 4                        Angola   1196.686957004252
# 5                    Antarctica                   0
# 6           Antigua and Barbuda                   0
# 7                     Argentina   702.3300313170606
# 8                       Armenia                   0
# 9                         Aruba                   0
# 10                    Australia   460.1342704607053
# 11                      Austria   24.90202726406311
# 12                   Azerbaijan   716.7350728223131
# 13                      Bahrain  188.54464845514946
# 14                   Bangladesh  13.405835402264056

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  226 non-null    object
#  1   2021     224 non-null    object
# dtypes: object(2)
# memory usage: 3.7+ KB

# %%
df3['2021'] = df3['2021'].replace(['--'], '0')

# %%
df3['2021'] = df3['2021'].fillna(0)

# %%
df3.rename(columns={'2021':'Production'}, inplace=True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     226 non-null    object
#  1   Production  226 non-null    object
# dtypes: object(2)
# memory usage: 3.7+ KB

# %%
df3.shape
# Out:
# (226, 2)

# %%
df4= df3.copy()

# %%
df4['Production'] = df4['Production'].astype(float)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     226 non-null    object
#  1   Production  226 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.7+ KB

# %%
df4.head()
# Out:
#                   Country   Production
# 0             Afghanistan     0.000000
# 1                 Albania    16.150553
# 2                 Algeria  1415.129339
# 3          American Samoa     0.000000
# 4                  Angola  1196.686957

# %%
df4["Ranking"]= df4["Production"].rank(ascending=False)

# %%
df4.head()
# Out:
#                   Country   Production  Ranking
# 0             Afghanistan     0.000000    170.5
# 1                 Albania    16.150553     82.0
# 2                 Algeria  1415.129339     16.0
# 3          American Samoa     0.000000    170.5
# 4                  Angola  1196.686957     18.0

# %%
df5= df4.sort_values("Ranking", ascending=True).reset_index(drop=True)

# %%
df5.head(20)
# Out:
#                          Country    Production  Ranking
# 0                  United States  18981.243493      1.0
# 1                   Saudi Arabia  10835.340692      2.0
# 2                         Russia  10776.717886      3.0
# 3                         Canada   5537.451003      4.0
# 4                          China   4993.069739      5.0
# 5                           Iraq   4149.022058      6.0
# 6           United Arab Emirates   3785.883804      7.0
# 7                         Brazil   3689.416939      8.0
# 8                           Iran   3457.531642      9.0
# 9                         Kuwait   2716.895738     10.0
# 10                        Norway   2030.847538     11.0
# 11                        Mexico   1923.657354     12.0
# 12                    Kazakhstan   1863.563248     13.0
# 13                         Qatar   1822.418328     14.0
# 14                       Nigeria   1650.392981     15.0
# 15                       Algeria   1415.129339     16.0
# ...

# %%
df5.tail()
# Out:
#                         Country  Production  Ranking
# 221                     Senegal   -0.027407    222.0
# 222                       Kenya   -0.031600    223.0
# 223          Dominican Republic   -0.096355    224.0
# 224                  Martinique   -0.264824    225.0
# 225                   Sri Lanka   -0.265851    226.0

# %%
df5["Production"]=df5["Production"]/1000

# %%
df5.head(11)
# Out:
#                          Country  Production  Ranking
# 0                  United States   18.981243      1.0
# 1                   Saudi Arabia   10.835341      2.0
# 2                         Russia   10.776718      3.0
# 3                         Canada    5.537451      4.0
# 4                          China    4.993070      5.0
# 5                           Iraq    4.149022      6.0
# 6           United Arab Emirates    3.785884      7.0
# 7                         Brazil    3.689417      8.0
# 8                           Iran    3.457532      9.0
# 9                         Kuwait    2.716896     10.0
# 10                        Norway    2.030848     11.0

# %%
df5["Production"]= df5["Production"].round(decimals =2)

# %%
df5.head(12)
# Out:
#                          Country  Production  Ranking
# 0                  United States       18.98      1.0
# 1                   Saudi Arabia       10.84      2.0
# 2                         Russia       10.78      3.0
# 3                         Canada        5.54      4.0
# 4                          China        4.99      5.0
# 5                           Iraq        4.15      6.0
# 6           United Arab Emirates        3.79      7.0
# 7                         Brazil        3.69      8.0
# 8                           Iran        3.46      9.0
# 9                         Kuwait        2.72     10.0
# 10                        Norway        2.03     11.0
# 11                        Mexico        1.92     12.0

# %%
df_top_ten_producers = df5.query('Ranking <= 10')

# %%
df_top_ten_producers.head(11)
# Out:
#                         Country  Production  Ranking
# 0                 United States       18.98      1.0
# 1                  Saudi Arabia       10.84      2.0
# 2                        Russia       10.78      3.0
# 3                        Canada        5.54      4.0
# 4                         China        4.99      5.0
# 5                          Iraq        4.15      6.0
# 6          United Arab Emirates        3.79      7.0
# 7                        Brazil        3.69      8.0
# 8                          Iran        3.46      9.0
# 9                        Kuwait        2.72     10.0

# %%
df_top_ten_producers["Production"].describe()
# Out:
# count    10.000000
# mean      6.894000
# std       5.151553
# min       2.720000
# 25%       3.715000
# 50%       4.570000
# 75%       9.470000
# max      18.980000
# Name: Production, dtype: float64

# %%
df_top_ten_producers.to_csv('Top_10_Oil_Producer_13_03_2022.csv',index=False)
